# %%
from sklearn.datasets import make_regression
import pandas as pd
import numpy as np

import plotly.express as px
import plotly.graph_objects as go

from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
X,y = make_regression(n_samples=100, n_features=2, n_informative=2, n_targets=1, noise=50)

# %%
df = pd.DataFrame({'feature1':X[:,0],'feature2':X[:,1],'target':y})

# %%
df.shape
# Out:
# (100, 3)

# %%
df.head()
# Out:
#    feature1  feature2      target
# 0 -0.122161  1.110221  190.998493
# 1 -0.256146 -1.079316 -148.655672
# 2  1.231643 -0.038586   80.292004
# 3 -0.256876 -1.595835 -170.359176
# 4  1.238645  0.863906  101.472222

# %%
fig = px.scatter_3d(df, x='feature1', y='feature2', z='target')

fig.show()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=3)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
print("MAE",mean_absolute_error(y_test,y_pred))
print("MSE",mean_squared_error(y_test,y_pred))
print("R2 score",r2_score(y_test,y_pred))
# Out:
# MAE 32.33794600838118
# MSE 1761.7482754616442
# R2 score 0.841383123597603

# %%
x = np.linspace(-5, 5, 10)
y = np.linspace(-5, 5, 10)
xGrid, yGrid = np.meshgrid(y, x)

z_final = lr.predict(final).reshape(10,10)

z = z_final

final = np.vstack((xGrid.ravel().reshape(1,100),yGrid.ravel().reshape(1,100))).T
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\WorkArea\Prep_Time\100-days-of-machine-learning-main\day50-multiple-linear-regression\multiple_linear_regression.ipynb Cell 13 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/d%3A/WorkArea/Prep_Time/100-days-of-machine-learning-main/day50-multiple-linear-regression/multiple_linear_regression.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a> y = np.linspace(-5, 5, 10)
#       <a href='vscode-notebook-cell:/d%3A/WorkArea/Prep_Time/100-days-of-machine-learning-main/day50-multiple-linear-regression/multiple_linear_regression.ipynb#X15sZmlsZQ%3D%3D?line=2'>3</a> xGrid, yGrid = np.meshgrid(y, x)
# ----> <a href='vscode-notebook-cell:/d%3A/WorkArea/Prep_Time/100-days-of-machine-learning-main/day50-multiple-linear-regression/multiple_linear_regression.ipynb#X15sZmlsZQ%3D%3D?line=4'>5</a> z_final = lr.predict(y).reshape(10,10)
#       <a href='vscode-notebook-cell:/d%3A/WorkArea/Prep_Time/100-days-of-machine-learning-main/day50-multiple-linear-regression/multiple_linear_regression.ipynb#X15sZmlsZQ%3D%3D?line=6'>7</a> z = z_final
#       <a href='vscode-notebook-cell:/d%3A/WorkArea/Prep_Time/100-days-of-machine-learning-main/day50-multiple-linear-regression/multiple_linear_regression.ipynb#X15sZmlsZQ%3D%3D?line=8'>9</a> final = np.vstack((xGrid.ravel().reshape(1,100),yGrid.ravel().reshape(1,100))).T
#
# File d:\Anaconda3_0608\lib\site-packages\sklearn\linear_model\_base.py:238, in LinearModel.predict(self, X)
#     224 def predict(self, X):
#     225     """
#     226     Predict using the linear model.
#     227
#    (...)
#     236         Returns predicted values.
#     237     """
# --> 238     return self._decision_function(X)
#
# File d:\Anaconda3_0608\lib\site-packages\sklearn\linear_model\_base.py:220, in LinearModel._decision_function(self, X)
#     217 def _decision_function(self, X):
#     218     check_is_fitted(self)
# --> 220     X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     221     return safe_sparse_dot(X, self.coef_.T,
#     222                            dense_output=True) + self.intercept_
#
# File d:\Anaconda3_0608\lib\site-packages\sklearn\utils\validation.py:63, in _deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      61 extra_args = len(args) - len(all_args)
#      62 if extra_args <= 0:
# ---> 63     return f(*args, **kwargs)
#      65 # extra_args > 0
#      66 args_msg = ['{}={}'.format(name, arg)
#      67             for name, arg in zip(kwonly_args[:extra_args],
#      68                                  args[-extra_args:])]
#
# File d:\Anaconda3_0608\lib\site-packages\sklearn\utils\validation.py:637, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     635     # If input is 1D raise error
#     636     if array.ndim == 1:
# --> 637         raise ValueError(
#     638             "Expected 2D array, got 1D array instead:\narray={}.\n"
#     639             "Reshape your data either using array.reshape(-1, 1) if "
#     640             "your data has a single feature or array.reshape(1, -1) "
#     641             "if it contains a single sample.".format(array))
#     643 # make sure we actually converted to numeric:
#     644 if dtype_numeric and array.dtype.kind in "OUSV":
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[-5.         -3.88888889 -2.77777778 -1.66666667 -0.55555556  0.55555556
#   1.66666667  2.77777778  3.88888889  5.        ].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
fig = px.scatter_3d(df, x='feature1', y='feature2', z='target')

fig.add_trace(go.Surface(x = x, y = y, z =z ))

fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\WorkArea\Prep_Time\100-days-of-machine-learning-main\day50-multiple-linear-regression\multiple_linear_regression.ipynb Cell 14 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/d%3A/WorkArea/Prep_Time/100-days-of-machine-learning-main/day50-multiple-linear-regression/multiple_linear_regression.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> fig = px.scatter_3d(df, x='feature1', y='feature2', z='target')
# ----> <a href='vscode-notebook-cell:/d%3A/WorkArea/Prep_Time/100-days-of-machine-learning-main/day50-multiple-linear-regression/multiple_linear_regression.ipynb#X16sZmlsZQ%3D%3D?line=2'>3</a> fig.add_trace(go.Surface(x = x, y = y, z =z ))
#       <a href='vscode-notebook-cell:/d%3A/WorkArea/Prep_Time/100-days-of-machine-learning-main/day50-multiple-linear-regression/multiple_linear_regression.ipynb#X16sZmlsZQ%3D%3D?line=4'>5</a> fig.show()
#
# NameError: name 'z' is not defined

# %%
lr.coef_
# Out:
# array([59.64518074, 13.20409431])

# %%
lr.intercept_
# Out:
# -7.55491251398082
